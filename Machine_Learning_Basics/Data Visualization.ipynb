# %% [markdown]
# ###  pip install matplotlib

# %% [markdown]
# ###  pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as py
import numpy as nump
# %matplotlib inline

# %%
data=pd.read_csv('Admission_Predict_Ver1.1.csv')

# %%
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
xaxis=data['GRE Score']
xaxis
# Out:
# 0      337
# 1      324
# 2      316
# 3      322
# 4      314
#       ...
# 495    332
# 496    337
# 497    330
# 498    312
# 499    327
# Name: GRE Score, Length: 500, dtype: int64

# %%
yaxis=data['Chance of Admit']
yaxis
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit, Length: 500, dtype: float64

# %% [markdown]
# ##  Scatter Plot

# %%
py.scatter(xaxis,yaxis)

# %%
data1=pd.read_csv('iphone_detail_cleaned.csv')
data1
# Out:
#     Unnamed: 0                                      Name    Offer  \
# 0            0          APPLE iPhone 14 (Purple, 128 GB)  14% off
# 1            1        APPLE iPhone 14 (Midnight, 128 GB)  14% off
# 2            2       APPLE iPhone 14 (Starlight, 128 GB)  14% off
# 3            3            APPLE iPhone 14 (Blue, 128 GB)  14% off
# 4            4        APPLE iPhone 13 (Midnight, 128 GB)  14% off
# 5            5           APPLE iPhone 13 (Green, 128 GB)  14% off
# 6            6       APPLE iPhone 13 (Starlight, 128 GB)  14% off
# 7            7            APPLE iPhone 13 (Pink, 128 GB)  14% off
# 8            8  APPLE iPhone 14 Plus (Starlight, 128 GB)  14% off
# 9            9   APPLE iPhone 14 Plus (Midnight, 128 GB)  14% off
# 10          10            APPLE iPhone 13 (Blue, 128 GB)  14% off
# 11          11       APPLE iPhone 14 Plus (Blue, 128 GB)  14% off
# 12          12     APPLE iPhone 14 Plus (Purple, 128 GB)  14% off
# ...

# %%
xaxis1=data1['Name']
xaxis1
# Out:
# 0             APPLE iPhone 14 (Purple, 128 GB)
# 1           APPLE iPhone 14 (Midnight, 128 GB)
# 2          APPLE iPhone 14 (Starlight, 128 GB)
# 3               APPLE iPhone 14 (Blue, 128 GB)
# 4           APPLE iPhone 13 (Midnight, 128 GB)
# 5              APPLE iPhone 13 (Green, 128 GB)
# 6          APPLE iPhone 13 (Starlight, 128 GB)
# 7               APPLE iPhone 13 (Pink, 128 GB)
# 8     APPLE iPhone 14 Plus (Starlight, 128 GB)
# 9      APPLE iPhone 14 Plus (Midnight, 128 GB)
# 10              APPLE iPhone 13 (Blue, 128 GB)
# 11         APPLE iPhone 14 Plus (Blue, 128 GB)
# 12       APPLE iPhone 14 Plus (Purple, 128 GB)
# 13             APPLE iPhone 11 (Black, 128 GB)
# 14             APPLE iPhone 11 (White, 128 GB)
# 15      APPLE iPhone 14 ((PRODUCT)RED, 128 GB)
# 16      APPLE iPhone 13 ((PRODUCT)RED, 128 GB)
# 17              APPLE iPhone 11 (White, 64 GB)
# 18          APPLE iPhone 14 (Midnight, 256 GB)
# 19         APPLE iPhone 14 (Starlight, 256 GB)
# ...

# %%
yaxis2=data1['Offer']
yaxis2
# Out:
# 0     14% off
# 1     14% off
# 2     14% off
# 3     14% off
# 4     14% off
# 5     14% off
# 6     14% off
# 7     14% off
# 8     14% off
# 9     14% off
# 10    14% off
# 11    14% off
# 12    14% off
# 13     7% off
# 14     7% off
# 15    16% off
# 16    14% off
# 17     4% off
# 18    13% off
# 19    13% off
# 20    12% off
# 21    13% off
# 22    13% off
# 23     4% off
# Name: Offer, dtype: object

# %%
py.bar(xaxis1,yaxis2)
# Out:
# <BarContainer object of 24 artists>

# %%
corrected=yaxis2.str.strip('% off').astype(str)
corrected
# Out:
# 0     14
# 1     14
# 2     14
# 3     14
# 4     14
# 5     14
# 6     14
# 7     14
# 8     14
# 9     14
# 10    14
# 11    14
# 12    14
# 13     7
# 14     7
# 15    16
# 16    14
# 17     4
# 18    13
# 19    13
# 20    12
# 21    13
# 22    13
# 23     4
# Name: Offer, dtype: object

# %%
py.bar(xaxis1,corrected)
# Out:
# <BarContainer object of 24 artists>

# %%
py.pie(corrected,labels=xaxis1)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d2575c7e20>,
# ...
#  [Text(1.0880409276597918, 0.1617619848333346, 'APPLE iPhone 14 (Purple, 128 GB)'),
#   Text(0.9939229065500308, 0.4712931739746915, 'APPLE iPhone 14 (Midnight, 128 GB)'),
#   Text(0.8138282877571719, 0.7400564289608124, 'APPLE iPhone 14 (Starlight, 128 GB)'),
#   Text(0.5633356664446872, 0.9448031154221076, 'APPLE iPhone 14 (Blue, 128 GB)'),
#   Text(0.26411322551010386, 1.0678221781320376, 'APPLE iPhone 13 (Midnight, 128 GB)'),
#   Text(-0.0579556116417544, 1.0984721876675942, 'APPLE iPhone 13 (Green, 128 GB)'),
#   Text(-0.3750111562406752, 1.0341018483181588, 'APPLE iPhone 13 (Starlight, 128 GB)'),
#   Text(-0.6596273807532, 0.880279341209751, 'APPLE iPhone 13 (Pink, 128 GB)'),
#   Text(-0.8871843327989831, 0.6503106639414915, 'APPLE iPhone 14 Plus (Starlight, 128 GB)'),
#   Text(-1.0379978171682152, 0.36408863145396414, 'APPLE iPhone 14 Plus (Midnight, 128 GB)'),
# ...

# %% [markdown]
# ##  Seaborn

# %%
import seaborn as s

# %%
s.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
s1=s.load_dataset('tips')
s1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
rand=nump.random.random(50)
rand
# Out:
# array([0.3021352 , 0.94234375, 0.50642643, 0.55214039, 0.20904683,
#        0.21863231, 0.19890459, 0.15535492, 0.31625109, 0.94989293,
#        0.75619397, 0.29699756, 0.41703026, 0.32203751, 0.05313443,
#        0.16893812, 0.85301289, 0.99690752, 0.52017377, 0.78890805,
#        0.43407923, 0.40954626, 0.47020548, 0.96369597, 0.53434023,
#        0.06179753, 0.09547835, 0.03093865, 0.43263922, 0.60983197,
#        0.84082042, 0.99169873, 0.50582192, 0.70303591, 0.70262396,
#        0.97861659, 0.44123643, 0.73640998, 0.33567816, 0.47345559,
#        0.59992467, 0.18722344, 0.09064606, 0.20991966, 0.25043402,
#        0.796349  , 0.33275   , 0.4612776 , 0.4620643 , 0.96027204])

# %%
s.histplot(rand)
# Out:
# <Axes: ylabel='Count'>

# %%
s.histplot(s1)
# Out:
# <Axes: ylabel='Count'>
