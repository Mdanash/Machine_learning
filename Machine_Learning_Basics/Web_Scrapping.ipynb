# %%
#pip install bs4

# %%
#pip install requests

# %%
from bs4 import BeautifulSoup

# %%
import requests
import pandas as pd
import numpy as np

# %%
url="https://www.imdb.com/list/ls044627954/"

# %%
response=requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
html=BeautifulSoup(response.text)
html
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Top 10 Movies of all time - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/list/ls044627954/" rel="canonical"/>
# ...

# %%
title=html.select(".lister-item-header a")

# %%
title
# Out:
# [<a href="/title/tt0407887/">The Departed</a>,
#  <a href="/title/tt0119217/">Good Will Hunting</a>,
#  <a href="/title/tt1375666/">Inception</a>,
#  <a href="/title/tt0816692/">Interstellar</a>,
#  <a href="/title/tt1345836/">The Dark Knight Rises</a>,
#  <a href="/title/tt0468569/">The Dark Knight</a>,
#  <a href="/title/tt0070735/">The Sting</a>,
#  <a href="/title/tt0060474/">La grande vadrouille</a>,
#  <a href="/title/tt0335266/">Lost in Translation</a>,
#  <a href="/title/tt0125439/">Notting Hill</a>,
#  <a href="/title/tt0110912/">Pulp Fiction</a>,
#  <a href="/title/tt1205489/">Gran Torino</a>,
#  <a href="/title/tt0062765/">Bullitt</a>,
#  <a href="/title/tt0105112/">Patriot Games</a>,
#  <a href="/title/tt0097576/">Indiana Jones and the Last Crusade</a>,
#  <a href="/title/tt0111161/">The Shawshank Redemption</a>,
#  <a href="/title/tt0437863/">The Benchwarmers</a>,
#  <a href="/title/tt0271668/">National Security</a>,
# ...

# %%
runtime=html.select(".runtime")
runtime
# Out:
# [<span class="runtime">151 min</span>,
#  <span class="runtime">126 min</span>,
#  <span class="runtime">148 min</span>,
#  <span class="runtime">169 min</span>,
#  <span class="runtime">164 min</span>,
#  <span class="runtime">152 min</span>,
#  <span class="runtime">129 min</span>,
#  <span class="runtime">132 min</span>,
#  <span class="runtime">102 min</span>,
#  <span class="runtime">124 min</span>,
#  <span class="runtime">154 min</span>,
#  <span class="runtime">116 min</span>,
#  <span class="runtime">114 min</span>,
#  <span class="runtime">117 min</span>,
#  <span class="runtime">127 min</span>,
#  <span class="runtime">142 min</span>,
#  <span class="runtime">85 min</span>,
#  <span class="runtime">88 min</span>,
#  <span class="runtime">202 min</span>,
#  <span class="runtime">99 min</span>,
#  <span class="runtime">115 min</span>,
#  <span class="runtime">148 min</span>,
#  <span class="runtime">127 min</span>,
#  <span class="runtime">128 min</span>,
# ...

# %%
rating=html.select(".ratings-metascore")
rating
# Out:
# [<div class="inline-block ratings-metascore">
#  <span class="metascore favorable">85        </span>
#          Metascore
#          </div>,
#  <div class="inline-block ratings-metascore">
#  <span class="metascore favorable">70        </span>
#          Metascore
#          </div>,
#  <div class="inline-block ratings-metascore">
#  <span class="metascore favorable">74        </span>
#          Metascore
#          </div>,
#  <div class="inline-block ratings-metascore">
#  <span class="metascore favorable">74        </span>
#          Metascore
#          </div>,
#  <div class="inline-block ratings-metascore">
#  <span class="metascore favorable">78        </span>
#          Metascore
#          </div>,
#  <div class="inline-block ratings-metascore">
#  <span class="metascore favorable">84        </span>
#          Metascore
#          </div>,
#  <div class="inline-block ratings-metascore">
#  <span class="metascore favorable">83        </span>
#          Metascore
# ...

# %%
details=pd.DataFrame(title,columns=['Movie name'])
details['Runtime']=runtime

# %%
details
# Out:
#                             Movie name    Runtime
# 0                         The Departed  [151 min]
# 1                    Good Will Hunting  [126 min]
# 2                            Inception  [148 min]
# 3                         Interstellar  [169 min]
# 4                The Dark Knight Rises  [164 min]
# 5                      The Dark Knight  [152 min]
# 6                            The Sting  [129 min]
# 7                 La grande vadrouille  [132 min]
# 8                  Lost in Translation  [102 min]
# 9                         Notting Hill  [124 min]
# 10                        Pulp Fiction  [154 min]
# 11                         Gran Torino  [116 min]
# 12                             Bullitt  [114 min]
# 13                       Patriot Games  [117 min]
# 14  Indiana Jones and the Last Crusade  [127 min]
# 15            The Shawshank Redemption  [142 min]
# 16                    The Benchwarmers   [85 min]
# 17                   National Security   [88 min]
# ...
